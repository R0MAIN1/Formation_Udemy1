# %%
import pandas as pd 
reviews = pd.read_csv("fandango_scores.csv")
#reviews
cols = ["FILM","RT_user_norm", "Metacritic_user_nom" ,"IMDB_norm","Fandango_Ratingvalue","Fandango_Stars"]
norm_reviews = reviews[cols]
norm_reviews[:3]
# Out:
#                              FILM  RT_user_norm  Metacritic_user_nom  \
# 0  Avengers: Age of Ultron (2015)           4.3                 3.55
# 1               Cinderella (2015)           4.0                 3.75
# 2                  Ant-Man (2015)           4.5                 4.05
#
#    IMDB_norm  Fandango_Ratingvalue  Fandango_Stars
# 0       3.90                   4.5             5.0
# 1       3.55                   4.5             5.0
# 2       3.90                   4.5             5.0

# %%
#Axes.bar(left,height)
#np.arrange()
#plt.bar soit axes.bar()
import matplotlib.pyplot as plt
fig, ax = plt.subplots()   #abreviation
#positionnement du cote gauche de chaque barre --> [1,2,3,4,5]
from numpy import arange
bar_position = arange(5) + 1
#Hauteur des barres.on choisit la moyenne des notes du premier film de notre dataset
num_cols = ["RT_user_norm", "Metacritic_user_nom" ,"IMDB_norm","Fandango_Ratingvalue","Fandango_Stars"]
bar_height = norm_reviews[num_cols].iloc[0].values
ax.bar(bar_position, bar_height)
plt.show()

# %%
import matplotlib.pyplot as plt

# Données pour l'exemple
categories = ['Catégorie 1', 'Catégorie 2', 'Catégorie 3', 'Catégorie 4']
valeurs = [25, 40, 30, 50]

# Création du graphique en barres
plt.bar(categories, valeurs, 0.8)

# Personnalisation du graphique
plt.xlabel('Catégories')
plt.ylabel('Valeurs')
plt.title('Diagramme en barres')

# Affichage du graphique
plt.show()

# %%
import matplotlib.pyplot as plt
from numpy import arange 

fig, ax = plt.subplots()

bar_position = arange(5) + 1

bar_heights = norm_reviews[num_cols].iloc[1].values 

ax.bar(bar_position, bar_heights, 0.5)
plt.show()

# %% [markdown]
# # aligner l'intitulé et le trait sur l'axe x

# %%
import matplotlib.pyplot as plt 
from numpy import arange

fig, ax = plt.subplots()
bar_position = arange(5) + 1
ticks_positions = range(1,6)

bar_heights = norm_reviews[num_cols].iloc[0].values 
ax.bar(bar_position,bar_heights, 0.5)
ax.set_xticks(ticks_positions)
ax.set_xticklabels(num_cols, rotation = 90)

ax.set_xlabel('source de notation')
ax.set_ylabel(' Note moyenne')
ax.set_title('Moyenne des notes utilisateurs du film Avangers')
plt.show()

# %% [markdown]
# # graphique a nuage de points

# %%
#axes.scatter(x,y)
import matplotlib.pyplot as plt 
from numpy import arange 

fig, ax = plt.subplots()
 
ax.scatter(norm_reviews['Fandango_Ratingvalue'], norm_reviews['RT_user_norm'])
ax.set_xlabel('Fandango')  
ax.set_ylabel('Rotten Tomatoes')


plt.show()

# %% [markdown]
# # intervertir les axes

# %%
fig = plt.figure(figsize=(5,10))
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)

ax1.scatter(norm_reviews['Fandango_Ratingvalue'], norm_reviews['RT_user_norm'])
ax1.set_xlabel('Fandango') 
ax1.set_ylabel('Rotten Tomatoes')

ax2.scatter(norm_reviews['RT_user_norm'], norm_reviews['Fandango_Ratingvalue'])
ax2.set_xlabel('Rotten Tomatoes')
ax2.set_ylabel('Fandango')
plt.show()

# %%
import matplotlib.pyplot as plt 

fig = plt.figure(figsize=(5,10))
ax1 = fig.add_subplot(3,1,1)
ax2 = fig.add_subplot(3,1,2)
ax3 = fig.add_subplot(3,1,3)

ax1.scatter(norm_reviews['Fandango_Ratingvalue'],norm_reviews['RT_user_norm'])
ax1.set_xlabel('Fandango')
ax1.set_ylabel('Rotten Tomattoes')
ax1.set_xlim(0,5)
ax1.set_ylim(0,5)

ax2.scatter(norm_reviews['Fandango_Ratingvalue'],norm_reviews['Metacritic_user_nom'])
ax2.set_xlabel('Fandango')
ax2.set_ylabel('Metacritic')
ax2.set_xlim(0,5)
ax2.set_ylim(0,5)

ax3.scatter(norm_reviews['Fandango_Ratingvalue'],norm_reviews['IMDB_norm'])
ax3.set_xlabel('Fandango')
ax3.set_ylabel('IMDB')
ax3.set_xlim(0,5)
ax3.set_ylim(0,5)

plt.show()

# %%
import matplotlib
from matplotlib import pyplot as plt

plt.bar(["Now", "1th Jan 2013"],
        [35, 39.5])
plt.show()
